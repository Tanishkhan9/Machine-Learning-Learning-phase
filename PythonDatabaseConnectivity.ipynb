# %%
import pymysql as sql

# %%
# pip install pymysql

# %%
conn = sql.connect(host='localhost', user='root', port=3306, password='')
conn

# %%
show databases;
# Out:
#   Cell In[3], line 1
#     show databases;
#          ^
# SyntaxError: invalid syntax

# %%
cur = conn.cursor()
cur

# %%
cur.execute("show databases")
# Out:
# 6

# %%
cur.fetchall()
# Out:
# (('arya_crt',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('phpmyadmin',),
#  ('test',))

# %%
cur.execute("use arya_crt")
# Out:
# 0

# %%
cur.execute("show tables")
cur.fetchall()
# Out:
# (('emp',), ('fees',), ('fullstack',), ('new',), ('students',))

# %%
cur.execute('select * from students')
cur.fetchall()
# Out:
# ((101, 'harsh', 23, 'jaipur'),
#  (102, 'sachin', 30, 'jaipur'),
#  (103, 'deep', 26, 'jaipur'),
#  (104, 'simran', 26, 'jaipur'),
#  (105, 'ravi', 22, 'jaipur'),
#  (106, 'rajat', 34, 'jaipur'))

# %%
conn.close()

# %%
cur.execute('show tables')
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cur.execute('show tables')
#       2 cur.fetchall()
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:562, in Connection.query(self, sql, unbuffered)
#     560 if isinstance(sql, str):
#     561     sql = sql.encode(self.encoding, "surrogateescape")
# ...

# %%
def db_connect():
    conn = sql.connect(host='localhost', user='root', port=3306, password='', database="arya_crt")
    cur = conn.cursor()
    return conn, cur

# %%
conn, cur = db_connect()

# %%
conn

# %%
cur

# %%
cur.execute('show tables')
cur.fetchall()
# Out:
# (('emp',), ('fees',), ('fullstack',), ('new',), ('students',))

# %%
cur.execute("insert into students values(108, 'ram', 23, 'jaipur')")
# Out:
# 1

# %%
conn.commit()

# %%
cur.execute("show tables")
cur.fetchall()
# Out:
# (('emp',), ('fees',), ('fullstack',), ('new',), ('students',))

# %%
cur.execute("select * from students")
cur.fetchall()
# Out:
# ((101, 'harsh', 23, 'jaipur'),
#  (102, 'sachin', 30, 'jaipur'),
#  (103, 'deep', 26, 'jaipur'),
#  (104, 'simran', 26, 'jaipur'),
#  (105, 'ravi', 22, 'jaipur'),
#  (106, 'rajat', 34, 'jaipur'),
#  (107, 'ravi', 23, 'jaipur'),
#  (108, 'ram', 23, 'jaipur'))

# %%
sid = int(input("Enter sid: "))
name = input("Enter name: ")
age = int(input("Enter age: "))
address = input("Enter address: ")

cmd = f"insert into students values({sid}, '{name}', {age}, '{address}')"
cur.execute(cmd)
# Out:
# Enter sid:  109
# Enter name:  rohan
# Enter age:  23
# Enter address:  jaipur
# 1

# %%
conn.commit()
