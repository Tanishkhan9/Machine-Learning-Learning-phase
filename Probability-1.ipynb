# %% [markdown]
# # Conditional Probability
#
# Conditional probability defines the probability of an event occurring based on a given condition or prior knowledge of another event.
#
# It is the likelihood of an event occurring, given that another event has already occurred. In probability, this is denoted as A given B, expressed as P(A | B), indicating the probability of event A when the event B has already occurred.

# %% [markdown]
# # Explanation of the above carousel:
#
# # ❓ Question
# What are the chances that its raining given that you carry an umbrella?
#
# ---
#
# ## 📌 Given
# - It rains **30%** of the time
# - You carry an umbrella **50%** of the time
# - When it rains, you carry an umbrella **80%** of the time
#
# ---
#
# ## 🔎 Implies (for 10 days scenario)
# - 3 out of 10 days are rainy (since $30\%$ of 10 = 3)
# - 5 out of 10 days you carry an umbrella (since $50\%$ of 10 = 5)
# - On rainy days, you carry it 2 out of 3 days (since $80\%$ of 3 ≈ 2)
#
# ---
#
# ## ☂️ Total Umbrella Days
# - Rainy days: **2 out of 3**
# - Sunny days: **3 out of 7**
# - Total umbrella days = **5** (matching the 50% probability)
#
# ---
#
# ## 📊 Conditional Probability
# Out of all umbrella days (5), only 2 days were rainy.
#
# $$
# P(\text{Rain} \mid \text{Carry Umbrella}) = \frac{2}{5} = 40\%
# $$

# %% [markdown]
# # Conditional Probability Formula
#
# Let's consider two events A and B, then the formula for the conditional probability of B when A has already occurred is given by:
#
# $$
# P(B \mid A) = \frac{P(B \cap A)}{P(A)}
# $$
#
# **Where:**
#
# - $P(A \cap B)$ represents the probability of both events $A$ and $B$ occurring simultaneously.
# - $P(A)$ represents the probability of event $A$ occurring.
# - **Note:** $P(A) > 0$ is required for $P(B \mid A)$ to be defined.
#
# **Steps to Find Probability of One Event Given Another Has Already Occurred**
#
# ## 🧮 Steps to Calculate Conditional Probability
#
#
# **Step 1:** Identify the events.
# Let’s call them **Event A** and **Event B**.
#
# **Step 2:** Determine the probability of Event A, i.e.,
# $$ P(A) $$
#
# **Step 3:** Determine the probability of Event B, i.e.,
# $$ P(B) $$
#
# **Step 4:** Determine the probability of both Event A and Event B occurring, i.e.,
# $$ P(A \cap B) $$
#
# **Step 5:** Apply the conditional probability formula and calculate the required probability:
# $$ P(B \mid A) = \frac{P(A \cap B)}{P(A)} $$

# %% [markdown]
# # 📘 Conditional Probability
#
# Conditional probability helps us understand the likelihood of an event occurring **given** that another event has already occurred.
#
# ---
#
# ## 🔹 Examples of Conditional Probability
#
# ### 1) Tossing a Coin
# - Event A: Getting a head on the first coin.
# - Event B: Getting a head on the second coin.
#
# Sample space: $S = \{HH, HT, TH, TT\}$
#
# The conditional probability of getting a head on the second coin (B) given that we got a head on the first coin (A) is:
#
# $$P(B|A) = P(B) = 0.5$$
#
# Since coin tosses are independent, the outcome of the first coin does not affect the second.
#
# ---
#
# ### 2) Drawing Cards
# - Event A: Drawing a red card on the first draw.
# - Event B: Drawing a red card on the second draw.
#
# After drawing one red card, there are 25 red cards and 51 total cards left.
#
# $$P(B|A) = \frac{25}{51} \approx 0.49$$
#
# ---
#
# ## 🔹 Properties of Conditional Probability
#
# 1. For an event $A$ in sample space $S$:
#    $$P(S|A) = P(A|A) = 1$$
#
# 2. For events $A$ and $B$, and event $X$ with $P(X) \neq 0$:
#    $$P((A \cup B)|X) = P(A|X) + P(B|X) - P((A \cap B)|X)$$
#
# 3. Order matters:
#    $$P(A|B) \neq P(B|A)$$
#
# 4. Complement Rule:
#    $$P(A'|B) = 1 - P(A|B)$$
#    But $$P(A|B') \neq 1 - P(A|B)$$
#
# 5. For independent events:
#    - Two events: $P(A \cap B) = P(A)P(B)$
#    - Three events: $P(A \cap B \cap C) = P(A)P(B)P(C)$
#
# ---
#
# ## 🔹 Conditional Probability and Independence
# If events $A$ and $B$ are independent:
#
# $$P(A|B) = P(A) \quad \text{and} \quad P(B|A) = P(B)$$
#
# ---
#
# ## 🔹 Multiplication Rule
# The multiplication rule links joint and conditional probabilities:
#
# $$P(A \cap B) = P(A) \times P(B|A)$$
#
# Steps:
# 1. Compute $P(A)$
# 2. Compute $P(B|A)$
# 3. Multiply
#
# ---
#
# ## 🔹 Applications
#
# - **Finance**: Risk management, loan defaults.
# - **Healthcare**: Diagnosing diseases with test results.
# - **Marketing**: Customer purchase predictions.
# - **Machine Learning**: Classification, recommendations.
# - **Weather Forecasting**: Predicting rain given prior conditions.
#
# ---
#
# ## 🔹 Solved Examples
#
# **Q1:** Bag has 5 red, 7 blue. Two balls drawn without replacement. Probability second is red given first is red?
#
# $P(A) = 5/12$
# $P(B|A) = 4/11$
#
# ---
#
# **Q2:** Among students:
# - Football = 70%
# - Basketball = 60%
# - Both = 40%
#
# $$P(A|B) = \frac{40}{60} = \frac{2}{3}$$
#
# ---
#
# **Q3:** City rains 30% of the time. Forecaster:
# - Predicts rain correctly 80% when it rains.
# - Predicts no rain correctly 90% when it doesn’t.
#
# $$P(R|F) = \frac{P(F|R)P(R)}{P(F)}$$
# $$P(F) = 0.8 \times 0.3 + 0.1 \times 0.7 = 0.31$$
# $$P(R|F) = \frac{0.24}{0.31} = 0.7742$$
#
# ---
#
# **Q4:** Die rolled twice. Sum even. Probability first roll even?
#
# Total even sum outcomes = 18
# Favorable (first even, sum even) = 9
#
# $$P(\text{First even | Sum even}) = \frac{9}{18} = \frac{1}{2}$$
#
# ---
#
# **Q5:** Bag with 4 red, 6 blue. First is blue, probability second is red?
#
# Remaining = 4 red, 5 blue.
#
# $$P(\text{Second red | First blue}) = \frac{4}{9} = 0.444$$
#
#
#
# ---
#
# ## Conditional Probability vs Joint Probability vs Marginal Probability
#
# The difference between **Conditional Probability**, **Joint Probability**, and **Marginal Probability** is given in the following table:
#
# | **Parameter**          | **Conditional Probability**                              | **Joint Probability**                                    | **Marginal Probability**                                |
# |-------------------------|----------------------------------------------------------|----------------------------------------------------------|----------------------------------------------------------|
# | **Definition**          | The probability of an event occurring given that another event has already occurred. | The probability of two or more events occurring simultaneously. | The probability of an event occurring without considering any other events. |
# | **Calculation**         | $ P(A \mid B) $                                          | $ P(A \cap B) $                                          | $ P(A) $                                                |
# | **Variables involved**  | Two or more events                                       | Two or more events                                       | Single event                                            |
#
#
# ---
#
# ## 🔹 Unsolved Problems
#
# 1. Deck of 52 cards. Two drawn without replacement. Probability second is a heart given first is a heart?
# 2. In a survey: 100 like ice cream, 50 like cake, 20 like both. Probability that a person likes cake given they like ice cream?
# 3. A box has 6 red and 4 green balls. Two drawn without replacement. Probability second is green given first was red?
# 4. Class of 30, 12 wear glasses, 8 of them male. Probability student is male given they wear glasses?
# 5. In a factory, 80% products are defective, 90% defective found in one warehouse. If a product is from that warehouse, what’s the probability it is defective?
